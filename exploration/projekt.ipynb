# %%
# !pip install pandas
# !pip install sklearn
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for sklearn: filename=sklearn-0.0.post1-py3-none-any.whl size=2936 sha256=9b15bd03cd8882b95feaa1b4f2dbeb408f9a067855edd729eb3bb8370566fd0a
#   Stored in directory: c:\users\sebas\appdata\local\pip\cache\wheels\f8\e0\3d\9d0c2020c44a519b9f02ab4fa6d2a4a996c98d79ab2f569fa1
# Successfully built sklearn
# ...

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
# Laden der Daten aus einer CSV-Datei
data = pd.read_csv('crop_recommendation.csv')
data
# Out:
#         N   P   K  temperature   humidity        ph    rainfall   label
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536    rice
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537    rice
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248    rice
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034    rice
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340    rice
# ...   ...  ..  ..          ...        ...       ...         ...     ...
# 1692  117  86  48    28.695620  82.541958  6.225225  116.161684  banana
# 1693  114  94  53    26.335449  76.853201  6.190757  118.685826  banana
# 1694  110  78  50    25.937302  78.898644  5.915569   98.217475  banana
# 1695   94  70  48    25.136865  84.883944  6.195152   91.464425  banana
# 1696   80  71  47    27.505277  80.797840  6.156373  105.077699  banana
#
# [1697 rows x 8 columns]

# %%
# Aufteilen der Daten in Features und Labels
X = data.drop('label', axis=1)
y = data['label']

# %%
# Teilen der Daten in Trainings- und Testdaten
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
# Erstellen eines Entscheidungsbaum-Klassifikators
clf = DecisionTreeClassifier()

# %%
# Trainieren des Algorithmus auf den Trainingsdaten
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
# Vorhersagen mit den Testdaten
y_pred = clf.predict(X_test)

# %%
y_pred
# Out:
# array(['beans', 'grapes', 'mango', 'mango', 'cotton', 'banana', 'beans',
#        'watermelon', 'rice', 'maize', 'apple', 'rice', 'orange', 'cotton',
#        'beans', 'peas', 'maize', 'apple', 'Soyabeans', 'beans', 'orange',
#        'rice', 'grapes', 'cowpeas', 'rice', 'orange', 'maize',
#        'Soyabeans', 'cotton', 'orange', 'coffee', 'mango', 'peas',
#        'maize', 'rice', 'groundnuts', 'watermelon', 'Soyabeans', 'cotton',
#        'Soyabeans', 'groundnuts', 'Soyabeans', 'rice', 'cowpeas',
#        'orange', 'maize', 'groundnuts', 'orange', 'grapes', 'rice',
#        'peas', 'rice', 'cowpeas', 'cotton', 'cotton', 'peas', 'orange',
#        'banana', 'groundnuts', 'maize', 'apple', 'rice', 'cowpeas',
#        'maize', 'coffee', 'maize', 'peas', 'groundnuts', 'rice',
#        'watermelon', 'banana', 'cotton', 'apple', 'cowpeas', 'watermelon',
#        'groundnuts', 'grapes', 'apple', 'grapes', 'mango', 'Soyabeans',
# ...

# %%
X_test
# Out:
#         N    P    K  temperature   humidity        ph    rainfall
# 326    21   63   17    15.773702  19.230316  5.979974  108.344141
# 948     8  127  196    27.027661  83.170939  5.833302   70.956660
# 880     1   29   29    27.329614  49.303472  6.052026   93.531974
# 886    27   21   30    35.391546  52.488231  5.061082   91.228811
# 1338  111   53   19    23.964360  78.027631  6.419537   84.631489
# ...   ...  ...  ...          ...        ...       ...         ...
# 817    26   37   30    35.399863  49.459626  6.166174   97.410540
# 1057  120   20   45    25.665760  88.698423  6.114129   54.227225
# 119    74   55   19    18.050337  62.893670  6.288868   84.236135
# 29     84   51   35    22.301574  80.644165  6.043305  197.979121
# 1298   40   17   15    21.350934  90.949297  7.871063  107.086209
#
# [340 rows x 7 columns]

# %%
# initialize list of lists
testing_data = [[5,31,27,28.33,49.73,5.28,93.54]]

#Fläche (ha), Wasserverbrauch für label raussuchen und hardcoden (mango = 10l/tag), Berechnung Wasserverbrauch pro Zeiteinheit für diese Fläche

# Create the pandas DataFrame
test_df = pd.DataFrame(testing_data, columns=['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall'])

# %%
test_df
# Out:
#    N   P   K  temperature  humidity    ph  rainfall
# 0  5  31  27        28.33     49.73  5.28     93.54

# %%
test_predict = clf.predict(test_df)

# %%
test_predict
# Out:
# array(['mango'], dtype=object)

# %%
accuracy = accuracy_score(y_test, y_pred)
accuracy
# Out:
# 0.9911764705882353
